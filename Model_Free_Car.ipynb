# %%
# prompt: link to drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.5 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Segmentation_data
# !wget https://app.roboflow.com/ds/4PCrjnYUoT?key=RPrPBejjcF
# Out:
# /content/drive/MyDrive/Segmentation_data
# --2025-05-09 09:15:26--  https://app.roboflow.com/ds/4PCrjnYUoT?key=RPrPBejjcF
# Resolving app.roboflow.com (app.roboflow.com)... 151.101.1.195, 151.101.65.195, 2620:0:890::100
# Connecting to app.roboflow.com (app.roboflow.com)|151.101.1.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-regional-exports/7WQu5I9UANXkg2F08SUrqWlmim13/oRlEmitwjCy2GmgK2Hep/1/yolov11.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20250509%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250509T091526Z&X-Goog-Expires=900&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
# %cd /content/drive/MyDrive/anacoda
# !unzip /content/drive/MyDrive/anacoda/freecar.zip
# Out:
# /content/drive/MyDrive/anacoda
# Archive:  /content/drive/MyDrive/anacoda/freecar.zip
#   inflating: freecar/data.yaml
#   inflating: freecar/README.dataset.txt
#   inflating: freecar/README.roboflow.txt
#    creating: freecar/test/
#    creating: freecar/test/images/
#   inflating: freecar/test/images/138_jpg.rf.1c798a60518c79615c0d6197a15a09f5.jpg
#   inflating: freecar/test/images/179_jpg.rf.dd2d03482760fd667af9ba076912c3c2.jpg
#   inflating: freecar/test/images/181_jpg.rf.0a88777ea50ec053e56841f37286b15b.jpg
#   inflating: freecar/test/images/191_jpg.rf.7f3efe58aaaf07ee4b6bfefbed0bc5ef.jpg
#   inflating: freecar/test/images/204_jpg.rf.69b91652476ab7848ea66e2cdae867c6.jpg
#   inflating: freecar/test/images/208_jpg.rf.467700f1f0bca9c6d3a5730e3b5f95d8.jpg
#   inflating: freecar/test/images/21_jpg.rf.0e9e04a89bf6afcc6b799b337a20a569.jpg
#   inflating: freecar/test/images/228_jpg.rf.a6af37a0a0994fbaa7c15630a9f48b28.jpg
# ...

# %%
# %cd /content/drive/MyDrive/anacoda/Free
# !yolo segment train data=/content/drive/MyDrive/anacoda/freecar/.yaml model=yolo11n-seg.pt epochs=100 imgsz=640 patience = 20
# Out:
# /content/drive/MyDrive/anacoda/Free
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# %cd /content/drive/MyDrive/Segmentation_data
# !yolo export model=/content/drive/MyDrive/Segmentation_data/runs/segment/train/weights/best.pt format=ncnn      # export official model
# Out:
# /content/drive/MyDrive/Segmentation_data
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.00GHz)
# YOLO11n-seg summary (fused): 113 layers, 2,834,763 parameters, 0 gradients, 10.2 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/Segmentation_data/runs/segment/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 37, 8400), (1, 32, 160, 160)) (5.7 MB)
#
# TorchScript: starting export with torch 2.6.0+cu124...
# TorchScript: export success ✅ 6.1s, saved as '/content/drive/MyDrive/Segmentation_data/runs/segment/train/weights/best.torchscript' (11.4 MB)
# requirements: Ultralytics requirement ['ncnn'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 3.5 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 7.0s, installed 1 package: ['ncnn']
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ...
